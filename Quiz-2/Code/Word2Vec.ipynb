# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
pip install pdfminer.six
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.6 MB 8.1 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 25.8 MB/s
# ...

# %%
from pdfminer.high_level import extract_text

# %%
text = extract_text('/content/drive/MyDrive/NLP/resume_final.pdf')
print(text)
# Out:
# Objective:-
#
# To reach the pinnacle of professional career, being in your university will help me get a
# better understanding of my subjects and have abundant opportunities to grow and explore in my
# field.
#
# PROJECTS:
#
# 1.Mini Project:
#
# Smart Door Lock
#
# Title:
# Duration:
#
# January-March 2017
#
# Objective: Our
#
# project is a raspberry pie based smart lock which can be unlocked and locked
#
# using smartphone.
#
# This smart lock is secure,simple,and easy to manage your home’s lock.This lock needs no
# keys and the lock is attached inside the door and you can control it from outside the door.
# As the lock is inside the door there is no way to break the lock.If we are outside and visitors
# are waiting for us,we can connect it through smartphone and open the door.
#
# Smart door lock working algorithm
#
# :
#
# 1 . In this project we have a raspberry pie board which
#
# ...

# %%
with open('/content/drive/MyDrive/NLP/resume_final.txt','w') as f:
  f.write(text)

# %%
import nltk

# %%
file_handler = open('/content/drive/MyDrive/NLP/resume_final.txt', 'r')
corpus2 = [nltk.word_tokenize(i) for i in str(file_handler.read()).split()]
file_handler.close()

# %%
from gensim.models import Word2Vec
# train model
model = Word2Vec(corpus2, min_count=1)
# Out:
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
words = list(model.wv.vocab)
print(str(words))
# Out:
# ['Objective', ':', '-', 'To', 'reach', 'the', 'pinnacle', 'of', 'professional', 'career', ',', 'being', 'in', 'your', 'university', 'will', 'help', 'me', 'get', 'a', 'better', 'understanding', 'my', 'subjects', 'and', 'have', 'abundant', 'opportunities', 'to', 'grow', 'explore', 'field', '.', 'PROJECTS', '1.Mini', 'Project', 'Smart', 'Door', 'Lock', 'Title', 'Duration', 'January-March', '2017', 'Our', 'project', 'is', 'raspberry', 'pie', 'based', 'smart', 'lock', 'which', 'can', 'be', 'unlocked', 'locked', 'using', 'smartphone', 'This', 'secure', 'simple', 'easy', 'manage', 'home', '’', 's', 'lock.This', 'needs', 'no', 'keys', 'attached', 'inside', 'door', 'you', 'control', 'it', 'from', 'outside', 'As', 'there', 'way', 'break', 'lock.If', 'we', 'are', 'visitors', 'waiting', 'for', 'us', 'connect', 'through', 'open', 'working', 'algorithm', '1', 'In', 'this', 'board', 'core', 'design', 'interfacing', 'with', 'locking', 'or', 'unlocking', 'same', 'controlled', 'by', 'servo', 'motors',
# ...

# %%
X = model[model.wv.vocab]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
import numpy as np
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
result = pca.fit_transform(X)

# %%
from matplotlib import pyplot
# Plot the points
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()

# %%
# Plot
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()
